# %% [markdown]
# collecting and processing data

# %% [markdown]
# print first 5 Rows

# %% [markdown]
# checking the number of row and columan

# %% [markdown]
# get Information .info()

# %% [markdown]
# checking th number of value is Null

# %% [markdown]
# checking the distribution of category data

# %% [markdown]
# encoding the categorys data --- replace values

# %% [markdown]
# spliting the data into training data and testing data

# %% [markdown]
# model training -- model

# %% [markdown]
# model evaluation -- predicts

# %% [markdown]
# visualization data in actual values and predicts values
